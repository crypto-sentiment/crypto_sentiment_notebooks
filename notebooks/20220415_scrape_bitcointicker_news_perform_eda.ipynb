# %% [markdown]
# #### Author
# Yury Kashnitsky
#
# #### Reference
# [Notion ticket](https://www.notion.so/a74951e4e815480584dea7d61ddce6cc?v=dbfdb1207d0e451b827d3c5041ed0cfd&p=9be8fa739ceb4eecbcd0000a6ae12fbc)
#
# #### Idea
# Scrape https://bitcointicker.co/news/ to get more unlabeled data. Perform basic EDA to come up with good rules for filtering.
#
# #### Results
#  - ~27k news titles are saved locally and to the `cryptonews.bitcointicker_news` Mongo collection
#  - Filtering based on presence of at least one verb seems to make sense
#  - Most of the titles under 4 words in length make no sense. Starting from 4 words is reasonable
#  - Placeholder titles need to be removed. E.g. "Bitcoin daily chart alert" is seen >90 times.

# %% [markdown]
# ## Scraping bitcointicker.co – the easy way (only 50)

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 0)
import requests
from bs4 import BeautifulSoup

# %%
URL = 'https://bitcointicker.co/news/'

# %%
def parse_bitcointicker(soup_object):
    
    parsed_titles, sources, pub_times = [], [], []
    
    # getting titles and sources
    for el in soup.find_all('div', attrs={'style': "overflow:hidden;"}):
        elem_text = el.get_text()
        title = elem_text.split(' - ')[0].strip()
        source = elem_text.split(' - ')[-1].strip()
        parsed_titles.append(title)
        sources.append(source)
    
    # getting publication times 
    for el in soup.find_all('div', attrs={'style': "margin-left:30px"}):
        elem_text = el.get_text()
        if "Posted" in elem_text:   # e.g. "Posted: 2022-04-15 06:00:19\n0 Comments"
            pub_time = elem_text.strip().split('\n')[0].replace('Posted:', '').strip()
            pub_times.append(pub_time)
            
    df = pd.DataFrame({'Title': parsed_titles, 'Source': sources, 'Pubtime': pub_times})
    
    return df

# %%
page = requests.get(URL)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
df = parse_bitcointicker(soup_object=soup)

# %%
len(df)
# Out:
# 50

# %%
df.head()
# Out:
#                                                                                         Title  \
# 0  Binance and Coinbase silent on Bitcoin Lightning: Community tries to understand why
# 1  Fumb Games Mobile App Bitcoin Miner Integrates Real BTC Rewards via Zebedee – Bitcoin News
# 2  US Links North Korean Hacker Groups To Axie Infinity Crypto Heist; Bitcoin Down By 3%
# 3  Cryptocurrency Prices Today April 15: Bitcoin, Ethereum edge lower; Dogecoin bucks trend
# 4  Crypto Taxes: Online Tax Software to Report Bitcoin, NFTs and Digital Currencies
#
#           Source              Pubtime
# 0  Cointelegraph  2022-04-15 06:43:53
# 1  Bitcoin News   2022-04-15 06:00:19
# 2  Outlook India  2022-04-15 04:24:20
# 3  Moneycontrol   2022-04-15 03:50:41
# 4  CNET           2022-04-15 01:15:03

# %% [markdown]
# ## Scraping bitcointicker.co – the harder way
#
# [Tutorial](https://medium.com/analytics-vidhya/using-python-and-selenium-to-scrape-infinite-scroll-web-pages-825d12c24ec7)
#
# Prereqs:
#  - [chromedriver](https://chromedriver.chromium.org/downloads) (for Mac - `brew install chromedriver`)
#  - `pip install selenium`

# %%
import time
from selenium import webdriver

CHROMEDRIVER_PATH = "/usr/local/bin/chromedriver"
TOTAL_PARSING_TIME = 3600 # secs to parse, still to figure out how to change to the number of elements parsed

# Web scrapper for infinite scrolling page 
driver = webdriver.Chrome(executable_path=CHROMEDRIVER_PATH)
driver.get(URL)
time.sleep(2)  # Allow 2 seconds for the web page to open
scroll_pause_time = 1 # You can set your own pause time. 
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1
start_time = time.time()

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
#     if (screen_height) * i > scroll_height * 1.1:
#         break
    if time.time() - start_time > TOTAL_PARSING_TIME:
        break
        
soup = BeautifulSoup(driver.page_source, "html.parser")
df = parse_bitcointicker(soup_object=soup)
print(f"{len(df)} titles parsed from {URL} in {TOTAL_PARSING_TIME} secs.")
# Out:
# /var/folders/xs/x4nxtnxd4qq06sg5z0x951q1q7mkqq/T/ipykernel_75469/1168228498.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=CHROMEDRIVER_PATH)
# 27550 titles parsed from https://bitcointicker.co/news/ in 3600 secs.

# %%
df.head()
# Out:
#                                                                                         Title  \
# 0  Binance and Coinbase silent on Bitcoin Lightning: Community tries to understand why
# 1  Fumb Games Mobile App Bitcoin Miner Integrates Real BTC Rewards via Zebedee – Bitcoin News
# 2  US Links North Korean Hacker Groups To Axie Infinity Crypto Heist; Bitcoin Down By 3%
# 3  Cryptocurrency Prices Today April 15: Bitcoin, Ethereum edge lower; Dogecoin bucks trend
# 4  Crypto Taxes: Online Tax Software to Report Bitcoin, NFTs and Digital Currencies
#
#           Source              Pubtime
# 0  Cointelegraph  2022-04-15 06:43:53
# 1  Bitcoin News   2022-04-15 06:00:19
# 2  Outlook India  2022-04-15 04:24:20
# 3  Moneycontrol   2022-04-15 03:50:41
# 4  CNET           2022-04-15 01:15:03

# %% [markdown]
# ##  Basic EDA and Filtering
#
# ### Selecting only news with a verb

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

def tag_verb_spacy(sent):
    # https://ashutoshtripathi.com/2020/04/13/parts-of-speech-tagging-and-dependency-parsing-using-spacy-nlp/
    doc = nlp(sent)
    
    verb_found = False
    for t in doc:
        if t.pos_ == 'VERB':
            verb_found = True
            
    return verb_found

# %%
df['has_verb'] = df['Title'].apply(lambda x: tag_verb_spacy(x))

# %%
df[df['has_verb']].head()
# Out:
#                                                                                         Title  \
# 0  Binance and Coinbase silent on Bitcoin Lightning: Community tries to understand why
# 1  Fumb Games Mobile App Bitcoin Miner Integrates Real BTC Rewards via Zebedee – Bitcoin News
# 3  Cryptocurrency Prices Today April 15: Bitcoin, Ethereum edge lower; Dogecoin bucks trend
# 4  Crypto Taxes: Online Tax Software to Report Bitcoin, NFTs and Digital Currencies
# 5  Saylor Calls MicroStrategy’s Bitcoin Play ‘Tremendous Success,’ Promises More BTC Buys
#
#           Source              Pubtime  has_verb
# 0  Cointelegraph  2022-04-15 06:43:53  True
# 1  Bitcoin News   2022-04-15 06:00:19  True
# 3  Moneycontrol   2022-04-15 03:50:41  True
# 4  CNET           2022-04-15 01:15:03  True
# 5  CoinDesk       2022-04-14 21:09:00  True

# %%
df[~df['has_verb']].head()
# Out:
#                                                                                     Title  \
# 2   US Links North Korean Hacker Groups To Axie Infinity Crypto Heist; Bitcoin Down By 3%
# 6   Clean Bitcoin: North Dakota To Double Its $3B Green Crypto Mining Efforts
# 11  Bitcoin Well CEO and CRO to Present at Alberta Technology Symposium
# 12  Escambia Co. Sheriff: Beware of Bitcoin scams
# 18  Report: Arcane Crypto Releases Bitcoin Lightning Network Research
#
#               Source              Pubtime  has_verb
# 2   Outlook India     2022-04-15 04:24:20  False
# 6   Benzinga          2022-04-14 21:08:50  False
# 11  GlobeNewswire     2022-04-14 20:30:00  False
# 12  WKRG News 5       2022-04-14 20:28:26  False
# 18  Bitcoin Magazine  2022-04-14 18:59:39  False

# %%
df.to_csv('../data/20220415_parsed_27k_bitcointicker_news_feb2021_apr2022.csv')

# %% [markdown]
# Examples having at least one verb make more sense as "news" - we'll further work only with those.

# %%
df['has_verb'].sum()
# Out:
# 21070

# %% [markdown]
# ## Sources

# %%
df['Source'].nunique()
# Out:
# 1511

# %%
df['Source'].value_counts().head()
# Out:
# Yahoo Finance       2225
# Bitcoin News        1991
# Cointelegraph       1683
# Bitcoin Magazine    1580
# CoinDesk            1517
# Name: Source, dtype: int64

# %% [markdown]
# ## Exact dupes
#
# Some placeholders are found. These can be ignored.

# %%
df['Title'].value_counts().head(10)
# Out:
# Bitcoin daily chart alert                                                                                            91
# Crypto Chartbook                                                                                                     17
# Bitcoin and Ethereum                                                                                                 15
# Bitcoin                                                                                                              7
# Bitcoin and Ripple's XRP                                                                                             6
# Bitcoin millionaire puts money on Greens in German election                                                          4
# Bitcoin Conference coming to College Station virtually, talking technology, business, finance, law and regulation    3
# Breakingviews                                                                                                        3
# Bitcoin Fails to Break $60K; Short-Term Support Near $56K                                                            2
# Market Wrap: Ether Trading Volume Up, Closing In on Bitcoin; Crypto Market Struggles                                 2
# Name: Title, dtype: int64

# %% [markdown]
# ### Short news

# %%
df['title_len_words'] = df['Title'].apply(lambda s: len(s.split()))

# %%
df['title_len_words'].value_counts().head()
# Out:
# 10    3664
# 11    3330
# 9     3203
# 12    2840
# 8     2548
# Name: title_len_words, dtype: int64

# %%
len(df[df['title_len_words'] < 4])
# Out:
# 160

# %% [markdown]
# Most of the titles under 4 words in length make no sense. There are exceptions of course "Forget Bitcoin", "Go buy Bitcoin", "Bitcoin crosses $50,000", etc. But there are not too many of them.

# %%
df.loc[df['has_verb'] & (df['title_len_words']  < 4)]
# Out:
#                                              Title                  Source  \
# 231    De-anonymizing Bitcoin                       Security Boulevard
# 478    Bitcoin Up Review                            Business 2 Community
# 841    UPDATE                                       GlobeNewswire
# 2918   Busting bitcoin bribers                      The Star Online
# 3379   Bitcoin Versions Compared                    iExpats.com
# 4299   Buy Bitcoin Now                              Forbes
# 4534   What to Buy                                  Analytics Insight
# 21123  Bypassing the Bitcoin Blockade
# 13424  Ways to Buy Bitcoins
# 8972   Phunware Acquires Additional Bitcoin
# 16453  About that Amazon-to-accept-bitcoin story
# 16569  Bitcoin rises above $40,000
# 444    When Bitcoin Meets Inflation
# 23909  Understanding Bitcoin Trading Technology
# 16570  Bitcoin rises above $40000
# 15649  Bitcoin: Outlook remains positive
# 22130  Bitcoin tumbles below $50K
# 2872   Bitcoin overtakes Russian Ruble
# 25574  Mulling Bitcoin and $100K
#
#                               Source              Pubtime  has_verb  \
# 2629   Bitcoin Magazine               2022-03-04 04:30:00  True
# 25111  Seeking Alpha                  2021-03-11 16:41:00  True
# 14032  Bitcoin Magazine               2021-09-08 22:25:44  True
# 7929   RTE.ie                         2021-12-08 11:16:34  True
# 1073   The Motley Fool                2022-03-29 11:15:00  True
# 26042  FX Empire                      2021-02-25 07:54:13  True
# 5227   New Zealand Herald             2022-01-22 20:00:00  True
# 963    Bitcoin Magazine               2022-03-30 19:00:00  True
# 26842  Livemint                       2021-02-15 08:33:29  True
# 26915  Forbes                         2021-02-13 14:41:37  True
# 15527  Bangkok Post                   2021-08-15 21:30:00  True
# 19325  ForexLive                      2021-06-07 20:54:12  True
# 26413  Moneyweb.co.za                 2021-02-19 22:55:26  True
# 10310  Seeking Alpha                  2021-11-03 00:25:00  True
# 12673  ForexLive                      2021-09-30 01:22:01  True
# 22674  The Australian Financial Revi  2021-04-16 14:00:16  True
# 5752   Seeking Alpha                  2022-01-14 16:55:00  True
# 2687   The New Republic               2022-03-03 11:08:42  True
# 21123  Hawaii Business Magazine       2021-05-12 17:14:14  True
# 13424  Robotics and Automation News   2021-09-19 23:24:19  True
# 8972   GlobeNewswire                  2021-11-22 13:30:00  True
# 16453  Financial Times                2021-07-30 10:19:50  True
# 16569  Reuters                        2021-07-28 02:37:00  True
# 444    Seeking Alpha                  2022-04-07 15:24:00  True
# 23909  Santa Clarita Valley Signal    2021-03-29 16:35:44  True
# 16570  Reuters                        2021-07-28 02:34:00  True
# 15649  FXStreet                       2021-08-13 06:00:00  True
# 22130  Yahoo Finance                  2021-04-23 20:14:28  True
# 2872   The Independent                2022-02-28 16:37:18  True
# 25574  Seeking Alpha                  2021-03-04 15:08:00  True
#
#        title_len_words
# 2629   4
# 25111  4
# 14032  4
# 7929   4
# 1073   4
# 26042  4
# 5227   4
# 963    4
# 26842  4
# 26915  4
# 15527  4
# 19325  4
# 26413  4
# 10310  4
# 12673  4
# 22674  4
# 5752   4
# 2687   4
# 21123  4
# 13424  4
# 8972   4
# 16453  4
# 16569  4
# 444    4
# 23909  4
# 16570  4
# 15649  4
# 22130  4
# 2872   4
# 25574  4

# %% [markdown]
# Most of the 5-word titles make sense.

# %%
df.loc[df['has_verb'] & (df['title_len_words']  == 5)].sample(30)
# Out:
#                                                  Title               Source  \
# 27     How can Bitcoin affect Prada?                    FingerLakes1.com
# 12269  Bitcoin rises 5% to $51711                       Reuters
# 10027  USU bitcoin club challenges stereotypes          Utahstatesman
